# %%
# %pip install timm

# %% [markdown]
# Hugging Face / timm에서 제공하는
# 사전학습(pretrained) ViT 모델을 불러와
# 실제 이미지 분류를 해보는 코드

# %%
# huggingface transformer vit
import torch
import torch.nn.functional as F
from torchvision import transforms
from PIL import Image
import numpy as np
import matplotlib.pyplot as plt
import requests
from io import BytesIO
import os, json


def use_huggingface_vit():
    '''huggingface transformers vit 로드'''
    try : 
        from transformers import ViTForImageClassification, ViTImageProcessor
        # 모델과 프로세스 로드
        model_name = 'google/vit-base-patch16-224'
        processor = ViTImageProcessor.from_pretrained(model_name)
        model = ViTForImageClassification.from_pretrained(model_name)
        model.eval()
        print(f'\n===[모델정보]===')
        print(f"모델의 파라미터 수 : {sum(p.numel() for p in model.parameters())}")
        print(f"모델의 클래스 수 : {model.config.num_labels}")
        print(f"모델의 이미지 : {model.config.image_size} ")
        print(f"모델의 패치 크기 : {model.config.patch_size}")
        print(f"모델의 히든크기 : {model.config.hidden_size}")
        print(f"모델의 레이어 수 : {model.config.num_hidden_layers}")
        print(f"모델의 어텐션 헤드 수 : {model.config.num_attention_heads}")
        return model, processor
    
    except Exception as e :
        print(f"huggingFace vit 로드 실패 : {e}")
        return None, None
    

# timm 라이브러리를 사용한 vit
def use_timm_vit():
    '''timm 라이브러리 vit'''
    import timm
    # 사용가능한 vit 모델 모록
    vit_models = timm.list_models('vit*', pretrained=True)
    for model_name in vit_models:
        if 'vit_base_patch16_224' in model_name:
            print(f"- {model_name}")
    print(f"총 {len(vit_models)}개 모델")

    model = timm.create_model('vit_base_patch16_224', pretrained = True)
    model.eval()
    print(f"실제 다운로드 모델명 : vit_base_patch16_224.{model.default_cfg['tag']}")


    # timm의 데이터 설정 가져오기
    data_config = timm.data.resolve_model_data_config(model)
    transforms = timm.data.create_transform(**data_config, is_training=False)
    return model, transforms



def classify_image_hf(model, processor, image):
    """Hugging Face 모델로 이미지 분류"""
    
    if model is None:
        print("  모델이 로드되지 않았습니다.")
        return None
    
    # 이미지 전처리
    inputs = processor(images=image, return_tensors="pt")
    print(f"\n[전처리된 입력]")
    print(f"  pixel_values shape: {inputs['pixel_values'].shape}")
    
    # 추론
    with torch.no_grad():
        outputs = model(**inputs)
    
    logits = outputs.logits
    print(f"\n[모델 출력]")
    print(f"  logits shape: {logits.shape}")
    
    # Top-5 예측
    probs = F.softmax(logits, dim=-1)
    top5_probs, top5_indices = torch.topk(probs, 5)
    
    print(f"\n[Top-5 예측 결과]")
    for i, (prob, idx) in enumerate(zip(top5_probs[0], top5_indices[0])):
        label = model.config.id2label[idx.item()]
        print(f"  {i+1}. {label}: {prob.item():.4f} ({prob.item()*100:.2f}%)")
    
    return top5_probs[0], top5_indices[0]




def classify_image_timm(model, transform, image):
    """timm 모델로 이미지 분류""" 
    
    if model is None:
        print("  모델이 로드되지 않았습니다.")
        return None
    
    # 이미지 전처리
    img_tensor = transform(image).unsqueeze(0)
    print(f"\n[전처리된 입력]")
    print(f"  tensor shape: {img_tensor.shape}")
    
    # 추론
    with torch.no_grad():
        outputs = model(img_tensor)
    
    print(f"\n[모델 출력]")
    print(f"  outputs shape: {outputs.shape}")
    
    # Top-5 예측
    probs = F.softmax(outputs, dim=-1)
    top5_probs, top5_indices = torch.topk(probs, 5)
    
    # ImageNet 클래스 이름 로드
    try:
        url = "https://raw.githubusercontent.com/pytorch/hub/master/imagenet_classes.txt"
        response = requests.get(url, timeout=10)
        categories = [s.strip() for s in response.text.splitlines()]
        
        print(f"\n[Top-5 예측 결과]")
        for i, (prob, idx) in enumerate(zip(top5_probs[0], top5_indices[0])):
            label = categories[idx.item()] if idx.item() < len(categories) else f"class_{idx.item()}"
            print(f"  {i+1}. {label}: {prob.item():.4f} ({prob.item()*100:.2f}%)")
            
    except Exception as e:
        print(f"\n[Top-5 예측 결과 (인덱스)]")
        for i, (prob, idx) in enumerate(zip(top5_probs[0], top5_indices[0])):
            print(f"  {i+1}. class_{idx.item()}: {prob.item():.4f} ({prob.item()*100:.2f}%)")
    
    return top5_probs[0], top5_indices[0]




if __name__ == '__main__':
    
    # 모델, 프리프로세스 로드 (huggingface, timm)
    hf_model, hf_process = use_huggingface_vit()
    timm_model, timm_process = use_timm_vit()
    # 샘플이미지 확보
    from glob import glob
    file_path = r'C:\00AI\LLM\20openai\13multimodal_food\food_test\apple_pie'
    files = glob(file_path+'/*.jpg')
    print(files)
    print('\n\n======= [timm 추론] ======')
    for file in files:
        test_img = Image.open(file).convert('RGB')
        filename = os.path.basename(file)
        print(f"\n--> 파일명 : {filename}")
        classify_image_timm(timm_model, timm_process, test_img)



    # # 모델, 프리프로세스 로드 (huggingface, timm)
    # hf_model, hf_process = use_huggingface_vit()
    # timm_model, timm_process = use_timm_vit()
    # # 샘플이미지 확보
    # hf 에서 받은 모델, timm에서 받은 모델로 전용 추론 함수에 넣어서 결과를 확인 
    # (ex. classify_image_time(timm_model, timm_process, img))
# Out:
# ===[모델정보]===
# 모델의 파라미터 수 : 86567656
# 모델의 클래스 수 : 1000
# 모델의 이미지 : 224
# 모델의 패치 크기 : 16
# 모델의 히든크기 : 768
# 모델의 레이어 수 : 12
# 모델의 어텐션 헤드 수 : 12
# - vit_base_patch16_224.augreg2_in21k_ft_in1k
# - vit_base_patch16_224.augreg_in1k
# - vit_base_patch16_224.augreg_in21k
# - vit_base_patch16_224.augreg_in21k_ft_in1k
# - vit_base_patch16_224.dino
# - vit_base_patch16_224.mae
# - vit_base_patch16_224.orig_in21k
# - vit_base_patch16_224.orig_in21k_ft_in1k
# - vit_base_patch16_224.sam_in1k
# - vit_base_patch16_224_miil.in21k
# - vit_base_patch16_224_miil.in21k_ft_in1k
# 총 333개 모델
# 실제 다운로드 모델명 : vit_base_patch16_224.augreg2_in21k_ft_in1k
# ['C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\134.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\136256.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\142332.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\156078.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\157083.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\168971.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\175848.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\182745.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\185537.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\21063.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\23893.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\38795.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\63651.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\64846.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\67826.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\68383.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\89035.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\98352.jpg', 'C:\\00AI\\LLM\\20openai\\13multimodal_food\\food_test\\apple_pie\\98449.jpg']
#
#
# ======= [timm 추론] ======
#
# --> 파일명 : 134.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.8239 (82.39%)
#   2. pizza: 0.0149 (1.49%)
#   3. bakery: 0.0057 (0.57%)
#   4. plate: 0.0038 (0.38%)
#   5. Dutch oven: 0.0018 (0.18%)
#
# --> 파일명 : 136256.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.3220 (32.20%)
#   2. honeycomb: 0.0613 (6.13%)
#   3. pizza: 0.0370 (3.70%)
#   4. French loaf: 0.0346 (3.46%)
#   5. waffle iron: 0.0326 (3.26%)
#
# --> 파일명 : 142332.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.7350 (73.50%)
#   2. bakery: 0.0877 (8.77%)
#   3. plate: 0.0125 (1.25%)
#   4. tray: 0.0085 (0.85%)
#   5. ice cream: 0.0041 (0.41%)
#
# --> 파일명 : 156078.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. ice cream: 0.8919 (89.19%)
#   2. bakery: 0.0075 (0.75%)
#   3. chocolate sauce: 0.0068 (0.68%)
#   4. plate: 0.0066 (0.66%)
#   5. eggnog: 0.0047 (0.47%)
#
# --> 파일명 : 157083.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. ice cream: 0.9043 (90.43%)
#   2. chocolate sauce: 0.0108 (1.08%)
#   3. bakery: 0.0052 (0.52%)
#   4. plate: 0.0038 (0.38%)
#   5. trifle: 0.0014 (0.14%)
#
# --> 파일명 : 168971.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. chocolate sauce: 0.5527 (55.27%)
#   2. ice cream: 0.1584 (15.84%)
#   3. plate: 0.0628 (6.28%)
#   4. trifle: 0.0060 (0.60%)
#   5. strawberry: 0.0032 (0.32%)
#
# --> 파일명 : 175848.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.6583 (65.83%)
#   2. plate: 0.0409 (4.09%)
#   3. burrito: 0.0306 (3.06%)
#   4. consomme: 0.0123 (1.23%)
#   5. hot pot: 0.0089 (0.89%)
#
# --> 파일명 : 182745.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. plate: 0.3040 (30.40%)
#   2. ice cream: 0.2966 (29.66%)
#   3. fig: 0.0534 (5.34%)
#   4. custard apple: 0.0439 (4.39%)
#   5. chocolate sauce: 0.0220 (2.20%)
#
# --> 파일명 : 185537.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. plate: 0.2892 (28.92%)
#   2. meat loaf: 0.1068 (10.68%)
#   3. French loaf: 0.0915 (9.15%)
#   4. chiton: 0.0480 (4.80%)
#   5. hotdog: 0.0418 (4.18%)
#
# --> 파일명 : 21063.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. ice cream: 0.7906 (79.06%)
#   2. chocolate sauce: 0.0715 (7.15%)
#   3. plate: 0.0083 (0.83%)
#   4. trifle: 0.0040 (0.40%)
#   5. mashed potato: 0.0028 (0.28%)
#
# --> 파일명 : 23893.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.8871 (88.71%)
#   2. frying pan: 0.0090 (0.90%)
#   3. Dutch oven: 0.0087 (0.87%)
#   4. dough: 0.0009 (0.09%)
#   5. pillow: 0.0008 (0.08%)
#
# --> 파일명 : 38795.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. plate: 0.1937 (19.37%)
#   2. pizza: 0.1538 (15.38%)
#   3. bakery: 0.1047 (10.47%)
#   4. bagel: 0.0769 (7.69%)
#   5. ice cream: 0.0552 (5.52%)
#
# --> 파일명 : 63651.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. plate: 0.3986 (39.86%)
#   2. ice cream: 0.1908 (19.08%)
#   3. chocolate sauce: 0.1508 (15.08%)
#   4. consomme: 0.0260 (2.60%)
#   5. fig: 0.0090 (0.90%)
#
# --> 파일명 : 64846.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. plate: 0.5989 (59.89%)
#   2. ice cream: 0.1064 (10.64%)
#   3. bakery: 0.0875 (8.75%)
#   4. chocolate sauce: 0.0189 (1.89%)
#   5. trifle: 0.0104 (1.04%)
#
# --> 파일명 : 67826.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.7781 (77.81%)
#   2. plate: 0.0230 (2.30%)
#   3. ice cream: 0.0115 (1.15%)
#   4. bakery: 0.0098 (0.98%)
#   5. French loaf: 0.0057 (0.57%)
#
# --> 파일명 : 68383.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.8756 (87.56%)
#   2. plate: 0.0117 (1.17%)
#   3. French loaf: 0.0054 (0.54%)
#   4. eggnog: 0.0034 (0.34%)
#   5. bakery: 0.0024 (0.24%)
#
# --> 파일명 : 89035.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. cheeseburger: 0.6838 (68.38%)
#   2. jackfruit: 0.0304 (3.04%)
#   3. guacamole: 0.0172 (1.72%)
#   4. magnetic compass: 0.0124 (1.24%)
#   5. hotdog: 0.0060 (0.60%)
#
# --> 파일명 : 98352.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.8777 (87.77%)
#   2. waffle iron: 0.0016 (0.16%)
#   3. dough: 0.0014 (0.14%)
#   4. frying pan: 0.0014 (0.14%)
#   5. spatula: 0.0011 (0.11%)
#
# --> 파일명 : 98449.jpg
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. potpie: 0.8219 (82.19%)
#   2. bakery: 0.0185 (1.85%)
#   3. French loaf: 0.0032 (0.32%)
#   4. dough: 0.0025 (0.25%)
#   5. eggnog: 0.0018 (0.18%)

# %%
# 추론해보기

from PIL import Image
import requests
from io import BytesIO

# hf_model, hf_process = use_huggingface_vit()
# timm_model, timm_process = use_timm_vit()

image_path = r"C:\00AI\LLM\20openai\14vit_image\cat.jpg"
image = Image.open(image_path).convert("RGB")

print("\n===== timm ViT 결과 =====")
classify_image_timm(timm_model, timm_process, image)

print("\n===== HuggingFace ViT 결과 =====")
classify_image_hf(hf_model, hf_process, image)
# Out:
# ===== timm ViT 결과 =====
#
# [전처리된 입력]
#   tensor shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   outputs shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. tiger cat: 0.6027 (60.27%)
#   2. Egyptian cat: 0.1188 (11.88%)
#   3. tabby: 0.0718 (7.18%)
#   4. lynx: 0.0218 (2.18%)
#   5. swab: 0.0161 (1.61%)
#
# ===== HuggingFace ViT 결과 =====
#
# [전처리된 입력]
#   pixel_values shape: torch.Size([1, 3, 224, 224])
#
# [모델 출력]
#   logits shape: torch.Size([1, 1000])
#
# [Top-5 예측 결과]
#   1. tiger cat: 0.4328 (43.28%)
#   2. tabby, tabby cat: 0.2598 (25.98%)
#   3. Egyptian cat: 0.1613 (16.13%)
#   4. broom: 0.0122 (1.22%)
#   5. swab, swob, mop: 0.0077 (0.77%)
# (tensor([0.4328, 0.2598, 0.1613, 0.0122, 0.0077]),
#  tensor([282, 281, 285, 462, 840]))
