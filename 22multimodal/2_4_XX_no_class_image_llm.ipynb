# %%
import os
from dotenv import load_dotenv
load_dotenv()

from langchain_openai import OpenAIEmbeddings, ChatOpenAI
from langchain_core.prompts import ChatPromptTemplate
from langchain_core.output_parsers import StrOutputParser

system_prompt = '''
당신은 와인 전문가로 다음 조건에 맞는 음식을 추천해 주세요. 이때 와인의 종류와 특징도 설명해주세요


역할:
1. 와인 & 음식 페어링:
나는 특정 요리와 와인을 상세하게 추천해서 풍미와 균형을 맞추고 전반적인 맛이 좋은 음식을 찾는다.
2. 와인 선택 가이드:
축하행사, 격식있는 저녁식사, 캐주얼한 모임 등 다양한 상황에 맞춰 행사 분위기와 어울리는 음식을 찾는다
3. 와인용어 설명:
복잡한 와인 용어를 쉽게 풀어 설명해서 포도 품종, 산지, 테이스팅 프로파일을 누구나 이해할 수 있도록 작성한다

'''

human_prompt = '''이 와인에 어울리는 요리를 추천해줘
    image_url : {image_url}

'''

prompt = ChatPromptTemplate.from_messages([
    ('system', system_prompt),
    ('human', human_prompt)
])

llm = ChatOpenAI(model = 'gpt-4o-mini')
chain = prompt | llm | StrOutputParser()
url = 'https://images.vivino.com/thumbs/tiV02HEuQPaNoSRcWA3r2g_pb_x600.png'
result = chain.invoke({'image_url':url})

print(result)
# Out:
# 제공된 와인 이미지를 기반으로 할 수는 없지만, 일반적으로 고급 레드 와인(틱스 레드 와인)과 잘 어울리는 음식 추천을 드리겠습니다. 주로 이 와인 타입은 시라(Syrah) 또는 까베르네 소비뇽(Cabernet Sauvignon)일 확률이 높으며, 풍부한 과일 향과 탄닌, 스파이시한 요소를 가지고 있을 것입니다. 이러한 특성을 반영하여 적절한 음식 조합을 추천하겠습니다.
#
# ### 추천 와인: 시라 또는 까베르네 소비뇽
#
# #### 음식 추천: 구운 양고기 스테이크
#
# - **요리 설명**: 양고기를 미리 마리네이드한 후 그릴에 구워 맛있는 겉표면을 만들어 줍니다. 로즈마리, 마늘, 올리브유, 소금, 후추로 간단히 마리네이트하여 고기의 풍미를 극대화합니다. 함께 구운 버섯과 구운 채소(예: 아스파라거스, 파프리카)와 곁들여 서빙합니다.
#
# #### 와인과 음식 페어링 설명:
# - **풍미 조화**: 구운 양고기의 육즙은 와인의 전반적인 비교적 높은 탄닌과 조화를 이루어 고기의 풍미를 더욱 돋보이게 합니다. 구운양고기의 고소한 맛은 레드 와인의 과일 향과 잘 어울리죠.
# - **산도와 균형**: 양고기의 기름진 맛은 레드 와인의 산도와 조화롭게 어우러져 전체적인 맛의 밸런스를 이루어냅니다.
#
# ### 와인 선택 가이드:
# 이러한 조합은 격식 있는 저녁식사뿐만 아니라 가족 모임이나 친구들과의 편안한 저녁식사에도 적합합니다. 특별한 경우에는 조금 더 고급스러운 디저트와 함께하는 것도 좋습니다.
#
# ### 와인 용어 설명:
# - **탄닌(Tannin)**: 포도의 껍질이나 씨앗에 존재하는 성분으로, 와인에 아삭아삭한 느낌을 주고 aging(숙성)과 관련이 깊습니다.
# - **산도(Acidity)**: 와인의 신맛을 결정하는 요소로, 산도가 높을수록 와인이 신선한 느낌을 줍니다. 주로 시트러스 과일의 맛을 느낄 수 있습니다.
# - **테이스팅 프로파일(Tasting Profile)**: 와인을 마셨을 때 느끼는 다양한 맛의 조합을 설명합니다. 예를 들어, 과일, 허브, 스파이스 등이 포함될 수 있습니다.
#
# 다음번에 어떤 와인을 선택하실지 결정하셨다면, 그에 맞는 요리에 대해 더 이야기해드리겠습니다!
