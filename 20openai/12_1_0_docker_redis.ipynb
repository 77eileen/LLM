# %% [markdown]
# https://www.docker.com/ ---> 윈도우 AMD64 설치 ----> 재부팅
# ----> 터미널에서 docker run -d --name redis-stack -p 6379:6379 -p 8001:8001 redis/redis-stack:latest
# ----> 상기 안될시,
#
# 이규영 강사 — 오전 9:25
# powershell 을 관리자 권한으로 실행
# [1]
# taskkill /F /IM "Docker Desktop.exe"
# taskkill /F /IM "com.docker.backend.exe"
# taskkill /F /IM "com.docker.proxy.exe"
# [2]
# net stop com.docker.service
# net start com.docker.service
# [3]
# 재시작 후에 다시
# [4]----> 터미널이나 cmd에서 docker run -d --name redis-stack -p 6379:6379 -p 8001:8001 redis/redis-stack:latest
# [5] docker-desktop 창에서 나오는거 확인
# [6] localhost:8001  확인

# %% [markdown]
# [5] docker-desktop 창에서 나오는거 확인
#
# ![{F03DF331-18FF-478E-99C6-484F4EF3E32C}.png](attachment:{F03DF331-18FF-478E-99C6-484F4EF3E32C}.png)

# %% [markdown]
# [6] 정상작동인지 확인 하기 localhost:8001  확인 (http://localhost:8001)
#
# ![{EF3E8BDC-786E-4934-AFF4-4F8F03344A3D}.png](attachment:{EF3E8BDC-786E-4934-AFF4-4F8F03344A3D}.png)

# %% [markdown]
# - 정상 작동인지 확인 (터미널에서 docker exec -it redis-stack redis-cli ping  ====> 입력시 pong)
#
# ![{63549C4C-62B0-4145-BC07-DE4EBD398F3C}.png](attachment:{63549C4C-62B0-4145-BC07-DE4EBD398F3C}.png)

# %% [markdown]
# ## docker
# - 내용 저장

# %%
# app.py ----------------> 메인
# vectorstore.py --------> 벡터스토어 관리
# config.py -------------> 설정
# documents/
    # sample.txt --------> RAG문서
